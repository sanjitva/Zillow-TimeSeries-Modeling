# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/zillow_data.csv')

# %%
df
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...

# %%
city_list = list(set([a for a in df['City']]))

# %%
metro_list = list(set([a for a in df['Metro']]))

# %%
county_list = list(set([a for a in df['CountyName']]))

# %%
county_list
# Out:
# ['Val Verde',
#  'Vanderburgh',
#  'Tarrant',
#  'Berks',
#  'Graham',
#  'Montcalm',
#  'Morton',
#  'Jessamine',
#  'Minidoka',
#  'Steele',
#  'Walker',
#  'Tolland',
#  'Callaway',
#  'McLean',
#  'Hendry',
#  'Leavenworth',
#  'Columbia',
#  'Clark',
#  'Isle of Wight',
#  'Anderson',
#  'Stephens',
#  'Ada',
#  'Hall',
#  'Wake',
#  'Watauga',
#  'Wichita',
#  'Ramsey',
#  'Ellis',
#  'Newport',
#  'Harris',
#  'Calcasieu',
#  'Cheboygan',
#  'Walthall',
#  'Trinity',
#  'Peach',
#  'Miller',
#  'Claiborne',
#  'Kimball',
#  'Pratt',
#  'Norfolk',
#  'Chautauqua',
#  'Clinton',
#  'Troup',
#  'Northumberland',
#  'Teton',
#  'Wakulla',
#  'Orleans',
#  'Harford',
#  'Finney',
#  'San Benito',
#  'Rowan',
#  'Montezuma',
#  'Craven',
#  'Pushmataha',
#  'Essex',
#  'Kings',
#  'Gaines',
#  'Pawnee',
#  'Caddo',
#  'Denton',
#  'Eastland',
#  'Milwaukee',
#  'Hartford',
#  'Jackson',
#  'Santa Rosa',
#  'Salem',
#  'Boone',
#  'Multnomah',
#  'Hernando',
#  'Williams',
# ...

# %%
df.sort_values('SizeRank')
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...
