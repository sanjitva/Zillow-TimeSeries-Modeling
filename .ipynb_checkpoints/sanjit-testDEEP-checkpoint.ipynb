# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %%
import warnings
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


import statsmodels.api as sm
from matplotlib.pylab import rcParams
plt.style.use('ggplot')

# %% [markdown]
# ## Helper Functions

# %%
def get_datetimes(df):
    """
    Takes a dataframe:
    returns only those column names that can be converted into datetime objects 
    as datetime objects.
    NOTE number of returned columns may not match total number of columns in passed dataframe
    """
    
    return pd.to_datetime(df.columns.values[7:], format='%Y-%m')


def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})



# Import the check_stationarity function from previous lab
def stationarity_check(TS):
    
    # Import adfuller
    from statsmodels.tsa.stattools import adfuller
    
    # Calculate rolling statistics
    roll_mean = TS.rolling(window=8, center=False).mean()
    roll_std = TS.rolling(window=8, center=False).std()
    
    # Perform the Dickey Fuller test
    dftest = adfuller(TS) 
    
    # Plot rolling statistics:
    fig = plt.figure(figsize=(12,6))
    orig = plt.plot(TS, color='blue',label='Original')
    mean = plt.plot(roll_mean, color='red', label='Rolling Mean')
    std = plt.plot(roll_std, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    # Print Dickey-Fuller test results
    print('Results of Dickey-Fuller Test: \n')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', 
                                             '#Lags Used', 'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    return None

# %% [markdown]
# # Data

# %%
#Loading our dataset
df = pd.read_csv('data/zillow_data.csv')

# %%
#Observing what our dataset looks like
df
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 0           Cook         1  334200.0  335400.0  336500.0  ...  1005500
# 1         Collin         2  235700.0  236900.0  236700.0  ...   308000
# 2         Harris         3  210400.0  212200.0  212200.0  ...   321000
# 3           Cook         4  498100.0  500900.0  503100.0  ...  1289800
# 4        El Paso         5   77300.0   77300.0   77300.0  ...   119100
# ...          ...       ...       ...       ...       ...  ...      ...
# 14718   Franklin     14719   94600.0   94300.0   94000.0  ...   216800
# 14719    Grafton     14720   92700.0   92500.0   92400.0  ...   202100
# 14720    Madison     14721   57100.0   57300.0   57500.0  ...   121800
# 14721   Gunnison     14722  191100.0  192400.0  193700.0  ...   662800
# 14722      Clark     14723  176400.0  176300.0  176100.0  ...   333800
#
#        2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0      1007500  1007800  1009600  1013300  1018700  1024400  1030700  1033800
# 1       310000   312500   314100   315000   316600   318100   319600   321100
# 2       320600   320200   320400   320800   321200   321200   323000   326900
# 3      1287700  1287400  1291500  1296600  1299000  1302700  1306400  1308500
# 4       119400   120000   120300   120300   120300   120300   120500   121000
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14718   217700   218600   218500   218100   216400   213100   209800   209200
# 14719   208400   212200   215200   214300   213100   213700   218300   222700
# 14720   122800   124600   126700   128800   130600   131700   132500   133000
# 14721   671200   682400   695600   695500   694700   706400   705300   681500
# 14722   336400   339700   343800   346800   348900   350400   353000   356000
#
#        2018-04
# 0      1030600
# 1       321800
# 2       329900
# 3      1307000
# 4       121500
# ...        ...
# 14718   209300
# 14719   225800
# 14720   133400
# 14721   664400
# 14722   357200
#
# [14723 rows x 272 columns]

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Narrowing the scope of our project

# %% [markdown]
# Our client is looking to purchase a home in the Miami-Dade county. We want to identify the best 5 Zip Codes which we believe will have the highest ROI after 3 years of purchase. i.e. We want the zipcodes that we believe will appreciate the most in value. These predictions will be mades using Time Series modeling.

# %% [markdown]
# ### Looking at our Florida data

# %%
#Dataframe containing only zips from Miami-Dade County

miami_dade =  df[df['CountyName']=='Miami-Dade']

# %%
#Observing what our Miami-Dade dataset looks like

miami_dade
# Out:
#        RegionID  RegionName                     City State  \
# 60        72463       33160        Sunny Isles Beach    FL
# 84        72442       33139              Miami Beach    FL
# 222       72488       33186            The Crossings    FL
# 226       72350       33012                  Hialeah    FL
# 376       72460       33157  Village of Palmetto Bay    FL
# ...         ...         ...                      ...   ...
# 8156      72473       33170                   Goulds    FL
# 8568      72484       33182                  Tamiami    FL
# 10524     72461       33158  Village of Palmetto Bay    FL
# 10580     72495       33194                  Tamiami    FL
# 10766     72369       33031                Homestead    FL
#
#                        Metro  CountyName  SizeRank   1996-04   1996-05  \
# 60     Miami-Fort Lauderdale  Miami-Dade        61  337300.0  337900.0
# 84     Miami-Fort Lauderdale  Miami-Dade        85  480200.0  480700.0
# 222    Miami-Fort Lauderdale  Miami-Dade       223  120600.0  120500.0
# 226    Miami-Fort Lauderdale  Miami-Dade       227  118400.0  118500.0
# 376    Miami-Fort Lauderdale  Miami-Dade       377  106400.0  106600.0
# ...                      ...         ...       ...       ...       ...
# 8156   Miami-Fort Lauderdale  Miami-Dade      8157   89500.0   89300.0
# 8568   Miami-Fort Lauderdale  Miami-Dade      8569  135800.0  136100.0
# 10524  Miami-Fort Lauderdale  Miami-Dade     10525  233800.0  234200.0
# 10580  Miami-Fort Lauderdale  Miami-Dade     10581  133200.0  132900.0
# 10766  Miami-Fort Lauderdale  Miami-Dade     10767  163400.0  163800.0
#
#         1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12  \
# 60     338300.0  ...  1466200  1471000  1485400  1497700  1504200  1507600
# 84     481200.0  ...  2917100  2925700  2942400  2958300  2946300  2912900
# 222    120500.0  ...   310600   311800   313700   314800   315300   317500
# 226    118500.0  ...   300300   302100   304500   306400   307200   308900
# 376    106800.0  ...   295600   298300   301600   304400   305900   307500
# ...         ...  ...      ...      ...      ...      ...      ...      ...
# 8156    89000.0  ...   247100   249700   252500   254300   254700   255800
# 8568   136300.0  ...   358100   359700   361100   362100   361400   361200
# 10524  234500.0  ...   621700   619900   618000   616500   616700   618200
# 10580  132700.0  ...   319700   321900   324100   325500   325400   325700
# 10766  164200.0  ...   391500   393800   395800   396600   396600   397500
#
#        2018-01  2018-02  2018-03  2018-04
# 60     1495800  1466200  1443900  1432300
# 84     2900900  2923300  2933600  2914100
# 222     320700   322800   323900   324500
# 226     311400   314100   317500   320500
# 376     309700   312500   316400   319800
# ...        ...      ...      ...      ...
# 8156    257700   259300   261800   264400
# 8568    362900   363500   362500   362000
# 10524   618500   621900   629500   634900
# 10580   327200   327800   327400   327000
# 10766   398700   401400   406400   410600
#
# [62 rows x 272 columns]

# %% [markdown]
# ## Number of ZipCodes for each City in the Miami-Dade County region

# %%
#Visualizing the value counts of zipcodes in each city in the Miami-Dade county

fig, ax = plt.subplots(figsize=(10,12))

y = [a for a in miami_dade['City'].value_counts()]

x = [a for a in miami_dade['City'].value_counts().keys()]

ax.barh(x,y);

# %% [markdown]
# We can see above that the city of Miami  has the highest number of zipcodes.

# %% [markdown]
# Our client has a budget of 300,000 Dollars so we want to help them purchase a property that has a price of 300,000 Dollars or less within the Miami-Dade County region.

# %%
miami_budget = miami_dade[miami_dade['2018-04']<=300000]

# %% [markdown]
# ## Selecting a ZipCode to build our Time Series model on

# %% [markdown]
# We want to build a Time Series model to predict the future ROI for each zip code in Miami-Dade County that would fit our client's budget. But first, we will select one specific zipcode to build our time series model on. For this purpose, we decided to find the zipcode that has seen the highest growth in the 3 years since our last recorded date - April, 2018.

# %%
#Creating a new column that shows the 3 year increase in value. From April, 2015 to April, 2018.
warnings.filterwarnings('ignore')

miami_budget['3_yr_ROI'] = None
miami_budget['3_yr_ROI'] = miami_budget['2018-04'].apply(lambda x : x-miami_budget['2015-04'])

# %%
#Identifying the ZipCode that grew the most between April,2015 and April,2018.

roi_df = miami_budget[['RegionName','3_yr_ROI']].sort_values('3_yr_ROI',ascending = False)

print(f'Highest growing Zipcode since April 2015 is : {int(roi_df.iloc[0][0])}')
# Out:
# Highest growing Zipcode since April 2015 is : 33126

# %% [markdown]
# We will run our first Time Series model on the ZipCode- 33126 to predict what its future value will be. Then we can run a similar model on other zipcodes in the state to identify which 5 zipcodes have the highest predicted ROI.

# %%
#Dataframe containining historical prices of the 33126 Zip Code.

zip33126 = df[df['RegionName']==33126]

# %%
# Time Series dataframe of 33126 Zip Code prices

series33126 = melt_data(zip33126)

# %%
#Observing our Time Series dataframe

series33126
# Out:
#                value
# time
# 1996-04-01  108600.0
# 1996-05-01  108800.0
# 1996-06-01  109100.0
# 1996-07-01  109400.0
# 1996-08-01  109700.0
# ...              ...
# 2017-12-01  294300.0
# 2018-01-01  295700.0
# 2018-02-01  296900.0
# 2018-03-01  298200.0
# 2018-04-01  298800.0
#
# [265 rows x 1 columns]

# %%
#Visualizing our Time Series Data for zipcode- 33126

fig, ax = plt.subplots(figsize=(20,12))
ax.plot(series33126)

ax.set_xlabel('Year', fontsize=30)
ax.set_ylabel('Price in 100,000($)',fontsize=20);

# %% [markdown]
# We can see from above that after several years of growth in the early years of the 21st Century, prices seemed to have likely fallen due to the economic crisis that emerged in 2008. Since around 2011 though, there has been an increase in prices but it is still yet to reach the average price level of its pre-recession peak.

# %% [markdown]
# We find that market conditions before the 2010s do not necessarily reflect the state of today's market. Therefore we chose to concentrate on modeling our Time Series only based on information from 2011.

# %%
recent_series = series33126['2011':]

# %%
#Visualizing our Time Series Data for zipcode- 33126 after 2010

fig, ax = plt.subplots(figsize=(20,12))
ax.plot(recent_series)

ax.set_xlabel('Year', fontsize=30)
ax.set_ylabel('Price in 100,000($)',fontsize=20);

# %% [markdown]
# We can now see a positive trend that displays a somewhat linear growth rate in average price.

# %% [markdown]
# # Modeling

# %% [markdown]
# Because of the fact that our model of choice happens to performing the preprocessing step of trend/seasonality elimination by itself, we will simply input the raw series into our model.

# %% [markdown]
# ## Splitting our data into Train and Test

# %%
# Splitting the last 36 months of our series as a test dataset.
train_series = recent_series[:'2015-04']
test_series = recent_series['2015-05':]

# %% [markdown]
# ## Fitting an AUTO-ARIMA Model
#
# We find that finding the optimal p,d & q values and then fitting an ARIMA model can be a time consuming approach especially if we want to iterate this process over every zip code in Miami. The benefit of using an AUTO-ARIMA model over an ARIMA model is that it helps eliminate the additional step of finding the optimal combination of p,d & q values and thereby it runs faster than an ARIMA model. The AUTO-ARIMA model performs this step for us and automatically plugs in the p,d & q value combination that returns the lowest AIC score.

# %%
import pmdarima as pm

auto_model = pm.auto_arima(train_series, start_p=0, start_q=0,
                     test='adf',
                     max_p=5, max_q=5,
                     m=1,
                     d=0,
                     seasonal = True,
                     start_P=0,start_Q=0,
                     D=0,
                     trace=True,
                     error_action= 'ignore',
                     suppress_warnings=True,
                     stepwise=True,with_intercept=False)



print(auto_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1396.530, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1363.669, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1358.531, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1359.598, Time=0.05 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=842.316, Time=0.29 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=839.299, Time=0.44 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1361.804, Time=0.33 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.61 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=841.794, Time=1.04 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1365.890, Time=0.09 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=0.70 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.47 sec
#
# Best model:  ARIMA(1,0,4)(0,0,0)[0]
# Total fit time: 5.094 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   52
# Model:               SARIMAX(1, 0, 4)   Log Likelihood                -413.650
# Date:                Wed, 25 Aug 2021   AIC                            839.299
# Time:                        21:51:23   BIC                            851.007
# Sample:                             0   HQIC                           843.788
#                                  - 52
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9998      0.001   1382.836      0.000       0.998       1.001
# ma.L1          1.8793      0.254      7.403      0.000       1.382       2.377
# ma.L2          1.7598      0.437      4.027      0.000       0.903       2.616
# ma.L3          0.9564      0.374      2.555      0.011       0.223       1.690
# ma.L4          0.4321      0.203      2.126      0.034       0.034       0.830
# sigma2      3.951e+05   4.86e-07   8.14e+11      0.000    3.95e+05    3.95e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.80   Jarque-Bera (JB):                 1.74
# Prob(Q):                              0.37   Prob(JB):                         0.42
# Heteroskedasticity (H):               2.43   Skew:                             0.14
# Prob(H) (two-sided):                  0.08   Kurtosis:                         2.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.02e+29. Standard errors may be unstable.

# %%
#Identifying the order values for our model
auto_model.order
# Out:
# (1, 0, 4)

# %%
#Identifying the Seasonal Order values for our model
auto_model.seasonal_order
# Out:
# (0, 0, 0, 0)

# %%
# Plug the optimal parameter values into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(train_series, 
                                        order=(1,0,4), 
                                        seasonal_order=(0, 0, 0, 0), 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
auto_model.plot_diagnostics(figsize=(18,18))
plt.show()
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0093      0.003    294.801      0.000       1.003       1.016
# ma.L1          1.6601      0.243      6.844      0.000       1.185       2.135
# ma.L2          1.3222      0.365      3.621      0.000       0.607       2.038
# ma.L3          0.5652      0.332      1.702      0.089      -0.086       1.216
# ma.L4          0.2680      0.206      1.299      0.194      -0.136       0.672
# sigma2      4.124e+05   2.85e-07   1.45e+12      0.000    4.12e+05    4.12e+05
# ==============================================================================

# %% [markdown]
# We want to ensure that our residuals are uncorrelated, normally distributed and have zero mean. If not, we need to tweak our model further.
#
# Let's check for these assumptions from diagnostics plots.
#
# * Top-right plot - ????????????
#
# * Our qq-plot shown on the bottom left displays that our residuals are somewhat following the linear trend line. This tells us that the residuals seen here are normally distributed.
#
# * The autocorrelation plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself.
#
# ????? These observations lead us to conclude that our model has no correlations and provides a satisfactory fit to help forecast future values.

# %%
# Get predictions starting from 04-01-2015 and calculate confidence intervals
pred = output.get_prediction(start=pd.to_datetime('2015-05'), end=pd.to_datetime('2018-04'), dynamic=False)
pred_conf = pred.conf_int()
pred_conf
# Out:
#               lower value    upper value
# 2015-05-01  208028.540551  210546.094898
# 2015-06-01  207100.887656  214276.897755
# 2015-07-01  206140.023408  218538.474241
# 2015-08-01  205611.654268  222609.302943
# 2015-09-01  205578.985113  226624.976402
# 2015-10-01  205866.335646  230357.677223
# 2015-11-01  206359.853106  233921.602751
# 2015-12-01  207002.295606  237374.342666
# 2016-01-01  207760.144012  240749.767125
# 2016-02-01  208611.820589  244069.808154
# 2016-03-01  209542.502456  247349.646218
# 2016-04-01  210541.512802  250600.319041
# 2016-05-01  211600.878761  253830.163757
# 2016-06-01  212714.475720  257045.672635
# 2016-07-01  213877.490720  260252.029710
# 2016-08-01  215086.070679  263453.462593
# 2016-09-01  216337.083193  266653.481699
# 2016-10-01  217627.948823  269855.047992
# 2016-11-01  218956.520418  273060.693701
# 2016-12-01  220320.994295  276272.611167
# 2017-01-01  221719.843594  279492.719521
# 2017-02-01  223151.767396  282722.715605
# 2017-03-01  224615.651291  285964.113432
# 2017-04-01  226110.536393  289218.275209
# 2017-05-01  227635.594702  292486.436008
# 2017-06-01  229190.109297  295769.723608
# 2017-07-01  230773.458245  299069.174622
# 2017-08-01  232385.101424  302385.747710
# 2017-09-01  234024.569628  305720.334506
# 2017-10-01  235691.455502  309073.768725
# 2017-11-01  237385.405938  312446.833801
# 2017-12-01  239106.115659  315840.269337
# 2018-01-01  240853.321774  319254.776591
# 2018-02-01  242626.799128  322691.023162
# 2018-03-01  244426.356316  326149.647017
# 2018-04-01  246251.832236  329631.259969

# %% [markdown]
# ## Testing our model performance

# %% [markdown]
# Now that we have received predictions for our training data, let us plot it against our test data to see how well our model can predict the next 36 months.

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

# Plot observed values
ax = recent_series.plot(label='observed')

# Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=0.9)

# Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightpink', alpha=0.5,label = 'Confidence Interval')

# Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# Our model was not perfectly accurate but it was able to capture the overall trend that truly occurred between April, 2015 and April, 2018. We can see now how our model would forecast the future until April, 2021- the point at which we will have reached 3 years from the purchase date of April, 2018.

# %%
## Getting a forecast for the next 72 months after the last recorded date on our dataset.
forecast = output.get_forecast(72)
prediction = forecast.conf_int()
prediction['value'] = forecast.predicted_mean
prediction.columns = ['lower','upper','prediction'] 
prediction
# Out:
#                     lower          upper     prediction
# 2015-05-01  208028.540551  210546.094898  209287.317724
# 2015-06-01  207100.887656  214276.897755  210688.892705
# 2015-07-01  206140.023408  218538.474241  212339.248825
# 2015-08-01  205611.654268  222609.302943  214110.478606
# 2015-09-01  205578.985113  226624.976402  216101.980757
# ...                   ...            ...            ...
# 2020-12-01  318305.982400  456157.131332  387231.556866
# 2021-01-01  321000.111703  460666.502613  390833.307158
# 2021-02-01  323722.750918  465214.365779  394468.558348
# 2021-03-01  326474.095409  469801.148668  398137.622039
# 2021-04-01  329254.344720  474427.280738  401840.812729
#
# [72 rows x 3 columns]

# %%
#Plotting our Forecast

fig, ax = plt.subplots()
train_series.plot(ax=ax,label='train values')


prediction['prediction'].plot(ax=ax,label='predicted value',ls='--')

ax.fill_between(x= prediction.index, y1= prediction['lower'], y2= prediction['upper'],color='lightpink',label='Confidence Interval')
ax.legend() 
plt.ylabel("Average Price")
plt.title('Average Home Price - 33126 - With Forcasted Value & Confidence Intervals')
plt.show()

# %% [markdown]
# # Modeling every Zip Code in Florida

# %%
#List of Zip Codes in the Miami-Fort Lauderdale metro region.
miami_budget_zips = [a for a in miami_budget['RegionName']]

# %%
zip_predictions = {}

for zipcode in miami_budget_zips:
    
    #Melting the time series of our given zipcode
    series = melt_data(df[df['RegionName']== zipcode])
    
    #Only taking data from 2011 onwards to more accurately reflect current market conditions
    recent_series = series['2011':]
    
    # Splitting the last 36 months of our series as a test dataset.
    train_series = recent_series[:'2015-04']
    test_series = recent_series['2015-05':]
    
    #Auto ARIMA model
    auto_model = pm.auto_arima(train_series, start_p=0, start_q=0,
                     test='adf',
                     max_p=5, max_q=5,
                     m=1,
                     d=0,
                     seasonal = True,
                     start_P=0,start_Q=0,
                     D=0,
                     trace=True,
                     error_action= 'ignore',
                     suppress_warnings=True,
                     stepwise=True,with_intercept=False)
   
    # Plug the optimal parameter values into a new SARIMAX model
    ARIMA_MODEL = sm.tsa.statespace.SARIMAX(train_series, 
                                            order= auto_model.order, 
                                            seasonal_order= auto_model.seasonal_order, 
                                            enforce_stationarity=False, 
                                            enforce_invertibility=False)

    # Fit the model and print results
    output = ARIMA_MODEL.fit()

    ## Getting a forecast for the next 72 months after the last absrecorded date on our dataset.
    forecast = output.get_forecast(72)
    prediction = forecast.conf_int()
    prediction['value'] = forecast.predicted_mean
    prediction.columns = ['lower','upper','prediction'] 
    
    #Adding the Zipcode's ROI to the zip_predictions dictionary
    zip_predictions[zipcode] = ((prediction['prediction'][-1]) - (series['value'][-1]))/ (series['value'][-1])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1375.899, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1343.108, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1338.230, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1339.468, Time=0.05 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.38 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#
# Best model:  ARIMA(0,0,2)(0,0,0)[0]
# Total fit time: 1.258 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1347.382, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1314.793, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1310.353, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.30 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1311.441, Time=0.06 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=797.707, Time=0.39 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.60 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1314.503, Time=0.07 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.39 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.36 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 3.297 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1396.530, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1363.669, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1358.531, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1359.598, Time=0.05 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=842.316, Time=0.31 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.40 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=839.299, Time=0.39 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1361.804, Time=0.07 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.49 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=841.794, Time=0.44 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1365.890, Time=0.09 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=0.51 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.47 sec
#
# Best model:  ARIMA(1,0,4)(0,0,0)[0]
# Total fit time: 3.789 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1373.521, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1340.036, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1334.739, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.38 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1335.511, Time=0.06 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=810.831, Time=0.32 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.40 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.42 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1338.192, Time=0.08 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=804.324, Time=0.45 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.23 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.45 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.39 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=inf, Time=0.54 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0]
# Total fit time: 4.482 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1386.258, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1353.456, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=883.004, Time=0.18 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.29 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1348.894, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.37 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.703 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1382.994, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1350.007, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1345.384, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=842.559, Time=0.33 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=835.193, Time=0.40 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1345.684, Time=0.06 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=832.003, Time=0.38 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1347.231, Time=0.07 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=835.376, Time=0.62 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=834.812, Time=0.48 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1348.130, Time=0.10 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=836.011, Time=0.53 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.43 sec
#
# Best model:  ARIMA(1,0,4)(0,0,0)[0]
# Total fit time: 4.655 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1358.238, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1325.455, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=871.765, Time=0.18 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1320.900, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.18 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.31 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.967 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1368.652, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1335.801, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=882.354, Time=0.13 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.24 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1330.581, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.49 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.784 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1365.427, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1332.124, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=835.426, Time=0.15 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.24 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1326.933, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.38 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=978.004, Time=0.49 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.922 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1359.919, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1327.113, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1322.633, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.25 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1323.902, Time=0.05 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#
# Best model:  ARIMA(0,0,2)(0,0,0)[0]
# Total fit time: 1.248 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1346.386, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1313.781, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=880.943, Time=0.25 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.29 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=836.391, Time=0.24 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1309.095, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.28 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=830.866, Time=0.32 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1310.699, Time=0.05 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1313.189, Time=0.07 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.50 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=830.509, Time=0.37 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(0,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=846.154, Time=0.51 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.53 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0] intercept
# Total fit time: 6.752 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1343.793, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1311.013, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1306.244, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1307.097, Time=0.05 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.30 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#
# Best model:  ARIMA(0,0,2)(0,0,0)[0]
# Total fit time: 1.148 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1392.359, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1359.719, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1355.088, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1353.514, Time=0.07 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=831.782, Time=0.36 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.55 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1357.473, Time=0.08 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.54 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.38 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 3.427 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1350.709, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1317.824, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=870.626, Time=0.15 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=834.197, Time=0.30 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1312.964, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=nan sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=835.577, Time=0.33 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1313.867, Time=0.06 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.41 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.39 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 2.383 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1391.626, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1358.830, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1354.033, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1355.359, Time=0.06 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=834.278, Time=0.36 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=828.714, Time=0.38 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1358.146, Time=0.07 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.49 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=inf, Time=0.44 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1362.140, Time=0.09 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=0.53 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#
# Best model:  ARIMA(1,0,4)(0,0,0)[0]
# Total fit time: 3.816 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1375.727, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1343.014, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1338.537, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=848.328, Time=0.23 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.41 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=850.549, Time=0.31 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1339.935, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.25 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.37 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 2.338 seconds

# %%
zip_predictions
# Out:
# {33125: -1.0,
#  33033: 0.5056657653780723,
#  33126: 0.34484877084577736,
#  33161: -0.04489983439790162,
#  33177: 0.3913782665332955,
#  33010: 0.16505950386825355,
#  33032: 0.44496398380246305,
#  33169: 0.1368664269831472,
#  33162: -0.1360569553162629,
#  33055: -1.0,
#  33056: 0.3486920061636199,
#  33030: -1.0,
#  33189: 0.6503671821903177,
#  33035: 0.4413210122020075,
#  33190: 0.26366312778992956,
#  33170: 0.3760559728587576}

# %%
# 3 year forecast for zipcodes
sort_orders = sorted(zip_predictions.items(), key=lambda x: x[1], reverse=True)

sorted_forecast_3yr = {}
for i in sort_orders:
	sorted_forecast_3yr[i[0]] = i[1]

# %%
# 3 year forecast for zipcodes arranged in descending order
sorted_forecast_3yr
# Out:
# {33189: 0.6503671821903177,
#  33033: 0.5056657653780723,
#  33032: 0.44496398380246305,
#  33035: 0.4413210122020075,
#  33177: 0.3913782665332955,
#  33170: 0.3760559728587576,
#  33056: 0.3486920061636199,
#  33126: 0.34484877084577736,
#  33190: 0.26366312778992956,
#  33010: 0.16505950386825355,
#  33169: 0.1368664269831472,
#  33161: -0.04489983439790162,
#  33162: -0.1360569553162629,
#  33125: -1.0,
#  33055: -1.0,
#  33030: -1.0}

# %%
top_5_zipcodes = list(sorted_forecast_3yr.items())[:5]

# %%
top_5_zipcodes
# Out:
# [(33189, 0.6503671821903177),
#  (33033, 0.5056657653780723),
#  (33032, 0.44496398380246305),
#  (33035, 0.4413210122020075),
#  (33177, 0.3913782665332955)]

# %%
top_5_zipcodes[0][0]
# Out:
# 33189

# %%
fig, ax = plt.subplots(figsize=(18,12))

x_labels = [33189,33033,33032,33035,33177]
x = [0,1,2,3,4]
y = [0.6503671821903177,0.5056657653780723,0.44496398380246305,0.4413210122020075,0.3913782665332955]

ax.bar(x, y, color='mediumslateblue')
ax.set_xticks(x)
ax.set_xticklabels(x_labels)
ax.set_yticks([0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7])
ax.set_yticklabels([0,'5%','10%','15%','20%','25%','30%','35%','40%','45%','50%','55%','60%','65%','70%'])
ax.set_title('Top 5 ZipCode Recommendations with the highest 3 year ROI', fontsize=20)
ax.set_ylabel('Average Forecasted 3 year ROI for each Zip Code', fontsize=20)
ax.set_xlabel('Top 5 Zipcodes',fontsize=20);
