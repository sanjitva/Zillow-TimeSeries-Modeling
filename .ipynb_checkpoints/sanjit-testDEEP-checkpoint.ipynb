# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %%
#Importing necessary Packages
import warnings
import itertools
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pylab import rcParams
# %matplotlib inline

# %% [markdown]
# ## Helper Functions

# %%
def get_datetimes(df):
    """
    Takes a dataframe:
    returns only those column names that can be converted into datetime objects 
    as datetime objects.
    NOTE number of returned columns may not match total number of columns in passed dataframe
    """
    
    return pd.to_datetime(df.columns.values[7:], format='%Y-%m')


def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    
    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank', 'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})



# Import the check_stationarity function from previous lab
def stationarity_check(TS):
    
    # Import adfuller
    from statsmodels.tsa.stattools import adfuller
    
    # Calculate rolling statistics
    roll_mean = TS.rolling(window=8, center=False).mean()
    roll_std = TS.rolling(window=8, center=False).std()
    
    # Perform the Dickey Fuller test
    dftest = adfuller(TS) 
    
    # Plot rolling statistics:
    fig = plt.figure(figsize=(12,6))
    orig = plt.plot(TS, color='blue',label='Original')
    mean = plt.plot(roll_mean, color='red', label='Rolling Mean')
    std = plt.plot(roll_std, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    # Print Dickey-Fuller test results
    print('Results of Dickey-Fuller Test: \n')

    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', 
                                             '#Lags Used', 'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    return None

# %% [markdown]
# # Business Understanding

# %% [markdown]
# Our client is looking to purchase a home in the Miami-Dade county after recently accepting a job offer over there. The client has established that they are not looking to spend over $300,000. The client specified that their current job offer is a 3 year contract and therefore there is a reasonable possibility that they may have to relocate after 3 years. Therefore, they have approached us to identify neighborhoods that have average prices under their budget and they also want to purchase a property that would give them the highest return on investment if they were to seel their property upon rellocation in 3 years. Our task is to identify the best 5 Zip Codes which we believe will have the highest ROI after 3 years of purchase. i.e. We want the zipcodes that we believe will appreciate the most in value. These predictions will be mades using Time Series modeling.

# %% [markdown]
# # Data

# %%
#Loading our dataset
df = pd.read_csv('data/zillow_data.csv')

# %%
#Observing what our dataset looks like
df
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 0           Cook         1  334200.0  335400.0  336500.0  ...  1005500
# 1         Collin         2  235700.0  236900.0  236700.0  ...   308000
# 2         Harris         3  210400.0  212200.0  212200.0  ...   321000
# 3           Cook         4  498100.0  500900.0  503100.0  ...  1289800
# 4        El Paso         5   77300.0   77300.0   77300.0  ...   119100
# ...          ...       ...       ...       ...       ...  ...      ...
# 14718   Franklin     14719   94600.0   94300.0   94000.0  ...   216800
# 14719    Grafton     14720   92700.0   92500.0   92400.0  ...   202100
# 14720    Madison     14721   57100.0   57300.0   57500.0  ...   121800
# 14721   Gunnison     14722  191100.0  192400.0  193700.0  ...   662800
# 14722      Clark     14723  176400.0  176300.0  176100.0  ...   333800
#
#        2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0      1007500  1007800  1009600  1013300  1018700  1024400  1030700  1033800
# 1       310000   312500   314100   315000   316600   318100   319600   321100
# 2       320600   320200   320400   320800   321200   321200   323000   326900
# 3      1287700  1287400  1291500  1296600  1299000  1302700  1306400  1308500
# 4       119400   120000   120300   120300   120300   120300   120500   121000
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14718   217700   218600   218500   218100   216400   213100   209800   209200
# 14719   208400   212200   215200   214300   213100   213700   218300   222700
# 14720   122800   124600   126700   128800   130600   131700   132500   133000
# 14721   671200   682400   695600   695500   694700   706400   705300   681500
# 14722   336400   339700   343800   346800   348900   350400   353000   356000
#
#        2018-04
# 0      1030600
# 1       321800
# 2       329900
# 3      1307000
# 4       121500
# ...        ...
# 14718   209300
# 14719   225800
# 14720   133400
# 14721   664400
# 14722   357200
#
# [14723 rows x 272 columns]

# %% [markdown]
# ## Looking at our Miami-Dade County data

# %%
#Dataframe containing only zips from Miami-Dade County

miami_dade =  df[df['CountyName']=='Miami-Dade']

# %%
#Observing what our Miami-Dade dataset looks like

miami_dade
# Out:
#        RegionID  RegionName                     City State  \
# 60        72463       33160        Sunny Isles Beach    FL
# 84        72442       33139              Miami Beach    FL
# 222       72488       33186            The Crossings    FL
# 226       72350       33012                  Hialeah    FL
# 376       72460       33157  Village of Palmetto Bay    FL
# ...         ...         ...                      ...   ...
# 8156      72473       33170                   Goulds    FL
# 8568      72484       33182                  Tamiami    FL
# 10524     72461       33158  Village of Palmetto Bay    FL
# 10580     72495       33194                  Tamiami    FL
# 10766     72369       33031                Homestead    FL
#
#                        Metro  CountyName  SizeRank   1996-04   1996-05  \
# 60     Miami-Fort Lauderdale  Miami-Dade        61  337300.0  337900.0
# 84     Miami-Fort Lauderdale  Miami-Dade        85  480200.0  480700.0
# 222    Miami-Fort Lauderdale  Miami-Dade       223  120600.0  120500.0
# 226    Miami-Fort Lauderdale  Miami-Dade       227  118400.0  118500.0
# 376    Miami-Fort Lauderdale  Miami-Dade       377  106400.0  106600.0
# ...                      ...         ...       ...       ...       ...
# 8156   Miami-Fort Lauderdale  Miami-Dade      8157   89500.0   89300.0
# 8568   Miami-Fort Lauderdale  Miami-Dade      8569  135800.0  136100.0
# 10524  Miami-Fort Lauderdale  Miami-Dade     10525  233800.0  234200.0
# 10580  Miami-Fort Lauderdale  Miami-Dade     10581  133200.0  132900.0
# 10766  Miami-Fort Lauderdale  Miami-Dade     10767  163400.0  163800.0
#
#         1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12  \
# 60     338300.0  ...  1466200  1471000  1485400  1497700  1504200  1507600
# 84     481200.0  ...  2917100  2925700  2942400  2958300  2946300  2912900
# 222    120500.0  ...   310600   311800   313700   314800   315300   317500
# 226    118500.0  ...   300300   302100   304500   306400   307200   308900
# 376    106800.0  ...   295600   298300   301600   304400   305900   307500
# ...         ...  ...      ...      ...      ...      ...      ...      ...
# 8156    89000.0  ...   247100   249700   252500   254300   254700   255800
# 8568   136300.0  ...   358100   359700   361100   362100   361400   361200
# 10524  234500.0  ...   621700   619900   618000   616500   616700   618200
# 10580  132700.0  ...   319700   321900   324100   325500   325400   325700
# 10766  164200.0  ...   391500   393800   395800   396600   396600   397500
#
#        2018-01  2018-02  2018-03  2018-04
# 60     1495800  1466200  1443900  1432300
# 84     2900900  2923300  2933600  2914100
# 222     320700   322800   323900   324500
# 226     311400   314100   317500   320500
# 376     309700   312500   316400   319800
# ...        ...      ...      ...      ...
# 8156    257700   259300   261800   264400
# 8568    362900   363500   362500   362000
# 10524   618500   621900   629500   634900
# 10580   327200   327800   327400   327000
# 10766   398700   401400   406400   410600
#
# [62 rows x 272 columns]

# %% [markdown]
# ## Number of ZipCodes for each City in the Miami-Dade County region

# %%
#Visualizing the value counts of zipcodes in each city in the Miami-Dade county

fig, ax = plt.subplots(figsize=(10,12))

y = [a for a in miami_dade['City'].value_counts()]

x = [a for a in miami_dade['City'].value_counts().keys()]

ax.barh(x,y);

# %% [markdown]
# We can see above that the city of Miami  has the highest number of zipcodes.

# %% [markdown]
# Our client has a budget of 300,000 Dollars so we want to help them purchase a property that has a price of 300,000 Dollars or less within the Miami-Dade County region.

# %%
miami_budget = miami_dade[miami_dade['2018-04']<=300000]

# %% [markdown]
# ## Selecting a ZipCode to build our Time Series model on

# %% [markdown]
# We want to build a Time Series model to predict the future ROI for each zip code in Miami-Dade County that would fit our client's budget. But first, we will select one specific zipcode to build our time series model on. For this purpose, we decided to find the zipcode that has seen the highest growth in the 3 years since our last recorded date - April, 2018.

# %%
#Creating a new column that shows the 3 year increase in value. From April, 2015 to April, 2018.
warnings.filterwarnings('ignore')

miami_budget['3_yr_ROI'] = None
miami_budget['3_yr_ROI'] = miami_budget['2018-04'].apply(lambda x : x-miami_budget['2015-04'])

# %%
#Identifying the ZipCode that grew the most between April,2015 and April,2018.

roi_df = miami_budget[['RegionName','3_yr_ROI']].sort_values('3_yr_ROI',ascending = False)

print(f'Highest growing Zipcode since April 2015 is : {int(roi_df.iloc[0][0])}')
# Out:
# Highest growing Zipcode since April 2015 is : 33126

# %% [markdown]
# We will run our first Time Series model on the ZipCode- 33126 to predict what its future value will be. Then we can run a similar model on other zipcodes in the state to identify which 5 zipcodes have the highest predicted ROI.

# %%
#Dataframe containining historical prices of the 33126 Zip Code.

zip33126 = df[df['RegionName']==33126]

# %%
# Time Series dataframe of 33126 Zip Code prices

series33126 = melt_data(zip33126)

# %%
#Observing our Time Series dataframe

series33126
# Out:
#                value
# time
# 1996-04-01  108600.0
# 1996-05-01  108800.0
# 1996-06-01  109100.0
# 1996-07-01  109400.0
# 1996-08-01  109700.0
# ...              ...
# 2017-12-01  294300.0
# 2018-01-01  295700.0
# 2018-02-01  296900.0
# 2018-03-01  298200.0
# 2018-04-01  298800.0
#
# [265 rows x 1 columns]

# %%
#Visualizing our Time Series Data for zipcode- 33126

fig, ax = plt.subplots(figsize=(20,12))
ax.plot(series33126)

ax.set_xlabel('Year', fontsize=30)
ax.set_ylabel('Price in 100,000($)',fontsize=20);

# %% [markdown]
# We can see from above that after several years of growth in the early years of the 21st Century, prices seemed to have likely fallen due to the economic crisis that emerged in 2008. Since around 2011 though, there has been an increase in prices but it is still yet to reach the average price level of its pre-recession peak.

# %% [markdown]
# We find that market conditions before the 2010s do not necessarily reflect the state of today's market. Therefore we chose to concentrate on modeling our Time Series only based on information from 2011.

# %%
recent_series = series33126['2011':]

# %%
#Visualizing our Time Series Data for zipcode- 33126 from 2011

fig, ax = plt.subplots(figsize=(20,12))
ax.plot(recent_series)

ax.set_xlabel('Year', fontsize=30)
ax.set_ylabel('Price in 100,000($)',fontsize=20);

# %% [markdown]
# We can now see a positive trend that displays a somewhat linear growth rate in average price.

# %% [markdown]
# # Modeling

# %% [markdown]
# Because our model of choice performs the preprocessing step of trend/seasonality removal by itself, we will simply input the raw series into our model.

# %% [markdown]
# ## Splitting our data into Train and Test

# %%
# Splitting the last 24 months of our series as a test dataset.
train_series = recent_series[:'2016-04']
test_series = recent_series['2016-05':]

# %% [markdown]
# ## Fitting an AUTO-ARIMA Model on our Training Series
#
# We find that finding the optimal p,d & q values and then fitting an ARIMA model can be a time consuming approach especially if we want to iterate this process over every zip code in Miami. The benefit of using an AUTO-ARIMA model over an ARIMA model is that it helps eliminate the additional step of finding the optimal combination of p,d & q values and thereby it runs faster than an ARIMA model. The AUTO-ARIMA model performs this step for us and automatically plugs in the p,d & q value combination that returns the lowest AIC score.

# %%
import pmdarima as pm

auto_model = pm.auto_arima(train_series, start_p=0, start_q=0,
                     test='adf',
                     max_p=5, max_q=5,
                     m=1,
                     d=0,
                     seasonal = True,
                     start_P=0,start_Q=0,
                     D=0,
                     trace=True,
                     error_action= 'ignore',
                     suppress_warnings=True,
                     stepwise=True,with_intercept=False)



print(auto_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1728.368, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1687.033, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1680.709, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.36 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1681.812, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1035.278, Time=0.50 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.81 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.55 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1684.647, Time=0.11 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.61 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.83 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.84 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 5.238 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   64
# Model:               SARIMAX(1, 0, 3)   Log Likelihood                -512.639
# Date:                Thu, 26 Aug 2021   AIC                           1035.278
# Time:                        12:00:46   BIC                           1046.072
# Sample:                             0   HQIC                          1039.530
#                                  - 64
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9998      0.001   1531.345      0.000       0.999       1.001
# ma.L1          1.8374      0.117     15.645      0.000       1.607       2.068
# ma.L2          1.5944      0.179      8.918      0.000       1.244       1.945
# ma.L3          0.5509      0.123      4.486      0.000       0.310       0.792
# sigma2       4.13e+05   2.27e-07   1.82e+12      0.000    4.13e+05    4.13e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.76   Jarque-Bera (JB):                 2.12
# Prob(Q):                              0.18   Prob(JB):                         0.35
# Heteroskedasticity (H):               2.31   Skew:                             0.42
# Prob(H) (two-sided):                  0.06   Kurtosis:                         2.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.77e+27. Standard errors may be unstable.

# %%
#Identifying the order values for our model
auto_model.order
# Out:
# (1, 0, 3)

# %%
#Identifying the Seasonal Order values for our model
auto_model.seasonal_order
# Out:
# (0, 0, 0, 0)

# %%
# Plug the optimal parameter values into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(train_series, 
                                        order=(1,0,3), 
                                        seasonal_order=(0, 0, 0, 0), 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
auto_model.plot_diagnostics(figsize=(18,18))
plt.show()
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0102      0.002    461.500      0.000       1.006       1.015
# ma.L1          1.5669      0.173      9.055      0.000       1.228       1.906
# ma.L2          1.1230      0.252      4.453      0.000       0.629       1.617
# ma.L3          0.2647      0.172      1.539      0.124      -0.072       0.602
# sigma2      3.637e+05    1.4e-07   2.59e+12      0.000    3.64e+05    3.64e+05
# ==============================================================================

# %% [markdown]
# We want to ensure that our residuals are uncorrelated, normally distributed and have zero mean. If not, we need to tweak our model further.
#
# Let's check for these assumptions from diagnostics plots.
#
# * Top-right plot - ????????????
#
# * Our qq-plot shown on the bottom left displays that our residuals are somewhat following the linear trend line. This tells us that the residuals seen here are normally distributed.
#
# * The autocorrelation plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself.
#
# ????? These observations lead us to conclude that our model has no correlations and provides a satisfactory fit to help forecast future values.

# %%
# Get predictions starting from 04-01-2015 and calculate confidence intervals
pred = output.get_prediction(start=pd.to_datetime('2016-05'), end=pd.to_datetime('2018-04'), dynamic=False)
pred_conf = pred.conf_int()
pred_conf
# Out:
#               lower value    upper value
# 2016-05-01  238782.632383  241146.759996
# 2016-06-01  239622.132300  246157.519806
# 2016-07-01  239976.013011  250945.571581
# 2016-08-01  240711.164686  255239.776193
# 2016-09-01  241802.432446  259229.389089
# 2016-10-01  243104.595623  263060.158789
# 2016-11-01  244554.245181  266796.027590
# 2016-12-01  246117.059965  270471.855371
# 2017-01-01  247772.062175  274109.164176
# 2017-02-01  249505.376021  277722.379611
# 2017-03-01  251307.299989  281321.758643
# 2017-04-01  253170.767815  284914.928677
# 2017-05-01  255090.469495  288507.766608
# 2017-06-01  257062.316425  292104.933737
# 2017-07-01  259083.099200  295710.218035
# 2017-08-01  261150.259564  299326.762249
# 2017-09-01  263261.733225  302957.221153
# 2017-10-01  265415.838368  306603.873091
# 2017-11-01  267611.194642  310268.701055
# 2017-12-01  269846.663028  313953.452880
# 2018-01-01  272121.300383  317659.686758
# 2018-02-01  274434.324514  321388.806238
# 2018-03-01  276785.086952  325142.087507
# 2018-04-01  279173.051449  328920.700961

# %% [markdown]
# ## Testing our model performance

# %% [markdown]
# Now that we have received predictions for our training data, let us plot it against our test data to see how well our model can predict the next 24 months.

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

# Plot observed values
ax = recent_series.plot(label='observed')

# Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=0.9)

# Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightpink', alpha=0.5,label = 'Confidence Interval')

# Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# Our model was not perfectly accurate but it was able to capture the overall trend that truly occurred between April, 2016 and April, 2018. We can see now how our model would forecast the future until April, 2021- the point at which we will have reached 3 years from the purchase date of April, 2018.

# %%
## Getting a forecast for the next 72 months after the last recorded date on our training series.
forecast = output.get_forecast(72)
prediction = forecast.conf_int()
prediction['value'] = forecast.predicted_mean
prediction.columns = ['lower','upper','prediction'] 
prediction
# Out:
#                     lower          upper     prediction
# 2016-05-01  238782.632383  241146.759996  239964.696189
# 2016-06-01  239622.132300  246157.519806  242889.826053
# 2016-07-01  239976.013011  250945.571581  245460.792296
# 2016-08-01  240711.164686  255239.776193  247975.470439
# 2016-09-01  241802.432446  259229.389089  250515.910767
# ...                   ...            ...            ...
# 2021-12-01  420677.678865  531549.453636  476113.566251
# 2022-01-01  424790.730561  537191.706384  480991.218472
# 2022-02-01  428948.585904  542889.095889  485918.840897
# 2022-03-01  433151.649974  548642.240934  490896.945454
# 2022-04-01  437400.333791  554451.764848  495926.049320
#
# [72 rows x 3 columns]

# %% [markdown]
# # Forecasting the Future

# %%
# Plug the parameter values from our Auto ARIMA model into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(recent_series, 
                                        order=(1,0,3), 
                                        seasonal_order=(0, 0, 0, 0), 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
full_output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0102      0.002    461.500      0.000       1.006       1.015
# ma.L1          1.5669      0.173      9.055      0.000       1.228       1.906
# ma.L2          1.1230      0.252      4.453      0.000       0.629       1.617
# ma.L3          0.2647      0.172      1.539      0.124      -0.072       0.602
# sigma2      3.637e+05    1.4e-07   2.59e+12      0.000    3.64e+05    3.64e+05
# ==============================================================================

# %%
## Getting a forecast for the next 36 months after the last recorded date on our dataset.
forecast = full_output.get_forecast(36)
future_prediction = forecast.conf_int()
future_prediction['value'] = forecast.predicted_mean
future_prediction.columns = ['lower','upper','prediction'] 
future_prediction
# Out:
#                     lower          upper     prediction
# 2018-05-01  297721.944672  300613.616330  299167.780501
# 2018-06-01  296339.248869  304476.173375  300407.711122
# 2018-07-01  296072.591251  309687.100707  302879.845979
# 2018-08-01  296711.291695  314640.398360  305675.845028
# 2018-09-01  297772.973115  319222.336898  308497.655007
# 2018-10-01  299085.123575  323605.904799  311345.514187
# 2018-11-01  300571.576440  327867.749637  314219.663038
# 2018-12-01  302190.836061  332049.852440  317120.344251
# 2019-01-01  303917.415661  336178.189848  320047.802755
# 2019-02-01  305734.385318  340270.186166  323002.285742
# 2019-03-01  307629.859550  344338.225819  325984.042684
# 2019-04-01  309595.144563  348391.506156  328993.325360
# 2019-05-01  311623.677295  352437.098441  332030.387868
# 2019-06-01  313710.378462  356480.594848  335095.486655
# 2019-07-01  315851.237931  360526.523138  338188.880535
# 2019-08-01  318043.038007  364578.623413  341310.830710
# 2019-09-01  320283.162447  368640.039141  344461.600794
# 2019-10-01  322569.460873  372713.452798  347641.456836
# 2019-11-01  324900.150127  376801.184549  350850.667338
# 2019-12-01  327273.740999  380905.265565  354089.503282
# 2020-01-01  329688.982792  385027.493515  357358.238153
# 2020-02-01  332144.820683  389169.475235  360657.147959
# 2020-03-01  334640.362475  393332.660037  363986.511256
# 2020-04-01  337174.852314  397518.366029  367346.609171
# 2020-05-01  339747.649684  401727.801174  370737.725429
# 2020-06-01  342358.212440  405962.080300  374160.146370
# 2020-07-01  345006.082972  410222.238989  377614.160980
# 2020-08-01  347690.876821  414509.245006  381100.060914
# 2020-09-01  350412.273242  418824.007787  384618.140515
# 2020-10-01  353170.007323  423167.386369  388168.696846
# 2020-11-01  355963.863358  427540.196071  391752.029714
# 2020-12-01  358793.669236  431943.214144  395368.441690
# 2021-01-01  361659.291677  436377.184604  399018.238141
# 2021-02-01  364560.632143  440842.822358  402701.727250
# 2021-03-01  367497.623330  445340.816767  406419.220049
# 2021-04-01  370470.226140  449871.834734  410171.030437

# %%
#Plotting our Forecast

fig, ax = plt.subplots()
recent_series.plot(ax=ax,label='Real Values')


future_prediction['prediction'].plot(ax=ax,label='predicted value',ls='--')

ax.fill_between(x= future_prediction.index, y1= future_prediction['lower'], y2= future_prediction['upper'],color='lightpink',label='Confidence Interval')
ax.legend() 
plt.ylabel("Average Price")
plt.title('Average Home Price - 33126 - With Forcasted Value & Confidence Intervals')
plt.show()

# %% [markdown]
# # Modeling every Zip Code in Florida

# %%
#List of Zip Codes in the Miami-Fort Lauderdale metro region.
miami_budget_zips = [a for a in miami_budget['RegionName']]

# %%
zip_predictions = {}

for zipcode in miami_budget_zips:
    
    #Melting the time series of our given zipcode
    series = melt_data(df[df['RegionName']== zipcode])
    
    #Only taking data from 2011 onwards to more accurately reflect current market conditions
    recent_series = series['2011':]
    
    # Splitting the last 36 months of our series as a test dataset.
    train_series = recent_series[:'2016-04']
    test_series = recent_series['2016-05':]
    
    #Auto ARIMA model
    auto_model = pm.auto_arima(train_series, start_p=0, start_q=0,
                     test='adf',
                     max_p=5, max_q=5,
                     m=1,
                     d=0,
                     seasonal = True,
                     start_P=0,start_Q=0,
                     D=0,
                     trace=True,
                     error_action= 'ignore',
                     suppress_warnings=True,
                     stepwise=True,with_intercept=False)
   
    # Plug the optimal parameter values for our Training data into a SARIMAX model that fits our entire series.
    ARIMA_MODEL = sm.tsa.statespace.SARIMAX(recent_series, 
                                            order= auto_model.order, 
                                            seasonal_order= auto_model.seasonal_order, 
                                            enforce_stationarity=False, 
                                            enforce_invertibility=False)

    # Fit the model and print results
    output = ARIMA_MODEL.fit()

    ## Getting a forecast for the next 36 months after the last absrecorded date on our dataset.
    forecast = output.get_forecast(36)
    prediction = forecast.conf_int()
    prediction['value'] = forecast.predicted_mean
    prediction.columns = ['lower','upper','prediction'] 
    
    #Adding the Zipcode's ROI to the zip_predictions dictionary
    zip_predictions[zipcode] = ((prediction['prediction'][-1]) - (series['value'][-1]))/ (series['value'][-1])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1707.388, Time=0.73 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=2.67 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1666.227, Time=0.93 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=8.31 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1660.104, Time=0.72 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=3.37 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1661.342, Time=1.31 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1038.249, Time=3.88 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=1.10 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=1034.440, Time=1.03 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1664.355, Time=0.17 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.95 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=inf, Time=0.98 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1667.878, Time=0.20 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=1.02 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.83 sec
#
# Best model:  ARIMA(1,0,4)(0,0,0)[0]
# Total fit time: 28.303 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1670.999, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1629.979, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1624.011, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1624.874, Time=0.10 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=991.429, Time=0.59 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.71 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=986.474, Time=0.68 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1629.123, Time=0.11 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.83 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=inf, Time=0.66 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1633.387, Time=0.14 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=0.77 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.71 sec
#
# Best model:  ARIMA(1,0,4)(0,0,0)[0]
# Total fit time: 6.172 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1728.368, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1687.033, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1680.709, Time=0.19 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1681.812, Time=0.08 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1035.278, Time=0.40 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.55 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.51 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1684.647, Time=0.09 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.44 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.60 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.57 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 4.156 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1700.281, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1658.521, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.19 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1651.544, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1652.224, Time=0.07 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#
# Best model:  ARIMA(0,0,2)(0,0,0)[0]
# Total fit time: 1.738 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1717.014, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1675.770, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1098.617, Time=0.27 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=1005.812, Time=0.41 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.18 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=1007.907, Time=0.63 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1038.293, Time=0.28 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1000.743, Time=0.54 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=997.976, Time=0.62 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.64 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=inf, Time=0.71 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=inf, Time=0.60 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=inf, Time=0.70 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=1037.234, Time=0.62 sec
#  ARIMA(5,0,3)(0,0,0)[0]             : AIC=inf, Time=0.81 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=1011.127, Time=0.69 sec
#
# Best model:  ARIMA(4,0,2)(0,0,0)[0]
# Total fit time: 8.404 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1712.166, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1670.866, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1664.540, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1069.327, Time=0.38 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.49 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1048.580, Time=0.34 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1665.114, Time=0.06 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.58 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=1049.598, Time=0.40 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1666.835, Time=0.08 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=1050.770, Time=0.57 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.40 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 3.653 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1684.109, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1642.929, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1079.348, Time=0.23 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1020.660, Time=0.23 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1636.825, Time=0.05 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.48 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1001.684, Time=0.36 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1638.298, Time=0.06 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.61 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=990.896, Time=0.48 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1641.626, Time=0.07 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=992.459, Time=0.47 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1645.460, Time=0.11 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=0.56 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=1037.299, Time=0.50 sec
#
# Best model:  ARIMA(1,0,4)(0,0,0)[0]
# Total fit time: 5.147 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1692.749, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1651.368, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1644.625, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1031.981, Time=0.27 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1024.057, Time=0.45 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1645.225, Time=0.06 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.44 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1647.511, Time=0.08 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.46 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 3.269 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1689.082, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1647.358, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1640.382, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1640.648, Time=0.07 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1009.325, Time=0.34 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=1000.886, Time=0.43 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1643.149, Time=0.08 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,5)(0,0,0)[0]             : AIC=1012.374, Time=0.53 sec
#  ARIMA(0,0,5)(0,0,0)[0]             : AIC=1645.130, Time=0.10 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=0.59 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.48 sec
#
# Best model:  ARIMA(1,0,4)(0,0,0)[0]
# Total fit time: 4.205 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1686.666, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1645.458, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1091.728, Time=0.28 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.24 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1639.321, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.19 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 1.823 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1669.841, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1628.516, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1090.339, Time=0.23 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1622.248, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=1025.853, Time=0.74 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=1017.109, Time=0.75 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.74 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=1020.015, Time=0.82 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=inf, Time=1.22 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=1.98 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=1.18 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=1020.167, Time=1.16 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.95 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[0]
# Total fit time: 10.752 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1666.040, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.13 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1624.776, Time=0.12 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1074.019, Time=0.51 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.38 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.53 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1618.658, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.41 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.88 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.80 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 3.936 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1724.008, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1682.851, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1676.743, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.59 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1677.861, Time=0.12 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1013.769, Time=0.80 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=1.34 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=0.94 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1681.272, Time=0.55 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=1.45 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=1050.026, Time=4.14 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=1.34 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 12.002 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1673.186, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1631.964, Time=0.17 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=1079.344, Time=1.06 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=1.56 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1036.949, Time=1.50 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1625.606, Time=0.16 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=1.96 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1037.546, Time=1.70 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1626.400, Time=0.46 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=3.12 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.11 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 14.098 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1719.913, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1678.544, Time=0.21 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.87 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1671.993, Time=0.54 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=2.73 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1672.797, Time=0.46 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=1024.681, Time=2.01 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=4.62 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=inf, Time=1.95 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=1675.866, Time=0.42 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=1.60 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=2.02 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.92 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 18.894 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1704.093, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1662.915, Time=0.17 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.54 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=1656.860, Time=0.15 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=1047.832, Time=1.24 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=1.30 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=1.25 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=1658.021, Time=0.17 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.87 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=2.28 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.85 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0]
# Total fit time: 9.170 seconds

# %%
#Looking at our 3 year ROI predictions
zip_predictions
# Out:
# {33125: 0.4709719854696541,
#  33033: 0.5473640576842268,
#  33126: 0.3727276788390636,
#  33161: -1.0,
#  33177: 0.4290426861576274,
#  33010: 0.4654536722328192,
#  33032: 0.49979218633465766,
#  33169: 0.4516428225153808,
#  33162: 0.5306867340258925,
#  33055: 0.560958838866512,
#  33056: 0.6274972837968116,
#  33030: 0.5729414493201569,
#  33189: 0.37965801216984685,
#  33035: 0.43487782134555514,
#  33190: 0.3177507838204503,
#  33170: 0.4665716211951121}

# %%
# Sorting our 3 year ROI forecast for zipcodes into descending order
sort_orders = sorted(zip_predictions.items(), key=lambda x: x[1], reverse=True)

sorted_forecast_3yr = {}
for i in sort_orders:
	sorted_forecast_3yr[i[0]] = i[1]

# %%
# 3 year forecast for zipcodes arranged in descending order
sorted_forecast_3yr
# Out:
# {33056: 0.6274972837968116,
#  33030: 0.5729414493201569,
#  33055: 0.560958838866512,
#  33033: 0.5473640576842268,
#  33162: 0.5306867340258925,
#  33032: 0.49979218633465766,
#  33125: 0.4709719854696541,
#  33170: 0.4665716211951121,
#  33010: 0.4654536722328192,
#  33169: 0.4516428225153808,
#  33035: 0.43487782134555514,
#  33177: 0.4290426861576274,
#  33189: 0.37965801216984685,
#  33126: 0.3727276788390636,
#  33190: 0.3177507838204503,
#  33161: -1.0}

# %%
#Selecting only the Top 5 Zips
top_5_zipcodes = list(sorted_forecast_3yr.items())[:5]

# %%
top_5_zipcodes
# Out:
# [(33056, 0.6274972837968116),
#  (33030, 0.5729414493201569),
#  (33055, 0.560958838866512),
#  (33033, 0.5473640576842268),
#  (33162, 0.5306867340258925)]

# %%
remaining_zipcodes = list(sorted_forecast_3yr.items())[5:]

# %%
remaining_zipcodes
# Out:
# [(33032, 0.49979218633465766),
#  (33125, 0.4709719854696541),
#  (33170, 0.4665716211951121),
#  (33010, 0.4654536722328192),
#  (33169, 0.4516428225153808),
#  (33035, 0.43487782134555514),
#  (33177, 0.4290426861576274),
#  (33189, 0.37965801216984685),
#  (33126, 0.3727276788390636),
#  (33190, 0.3177507838204503),
#  (33161, -1.0)]

# %%
avg_ROI_other_zips = sum([a[1] for a in remaining_zipcodes])/len(([a[1] for a in remaining_zipcodes]))

# %%
avg_ROI_other_zips
# Out:
# 0.29895357000728795

# %%
fig, ax = plt.subplots(figsize=(18,12))

x_labels = [top_5_zipcodes[0][0],top_5_zipcodes[1][0],top_5_zipcodes[2][0],top_5_zipcodes[3][0],top_5_zipcodes[4][0]]
x = [1,2,3,4,5]
y = [top_5_zipcodes[0][1],top_5_zipcodes[1][1],top_5_zipcodes[2][1],top_5_zipcodes[3][1],top_5_zipcodes[4][1]]

ax.bar(x, y, color='mediumslateblue')
ax.axhline(y=avg_ROI_other_zips,label = 'Average ROI for remaining Zips')
ax.set_xticks(x)
ax.set_xticklabels(x_labels)
ax.set_yticks([0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7])
ax.set_yticklabels([0,'5%','10%','15%','20%','25%','30%','35%','40%','45%','50%','55%','60%','65%','70%'])
ax.set_title('Top 5 ZipCode Recommendations with the highest 3 year ROI', fontsize=20)
ax.set_ylabel('Average Forecasted 3 year ROI for each Zip Code', fontsize=20)
ax.set_xlabel('Top 5 Zipcodes',fontsize=20)
ax.legend();
